# %%
import numpy as np
import scipy.special
import pandas as pd

from bokeh.layouts import gridplot
from bokeh.plotting import figure
from bokeh.models import Range1d, ColumnDataSource
from ipywidgets import interact
from bokeh.io import show, push_notebook, output_notebook
output_notebook()

p1 = figure(title="",tools="save",
            background_fill_color="#E8DDCB")

#read in fakes
fakes  = pd.read_csv('../data/FakeBackground.csv',names = ['Lep1Pt','Lep2Pt','Jet1Pt','Jet2Pt','HT','nConst','DilepMass','weight','nTL'])
#add smearing for visualization                                                                                                                                                                                    
fakes['Smear'] = np.random.normal(0,0.3,len(fakes))
fakes['nConstSmeared'] = fakes['nConst']+fakes['Smear']
#define column data source for fakes
fakeSource = ColumnDataSource(data=dict(HT=[], nConst=[],weights=[]))

#define selection for fakes
def getFakesData(ht,nc):
    #selected = fakes[(fakes['HT'] >= ht) & (fakes['nConstSmeared'] >= nc)]
    selected = fakes[
        (fakes.HT >= ht) &
        (fakes.nConstSmeared >= nc)
    ]
    return selected

#read in signal
signal  = pd.read_csv('../data/Signal.csv',names = ['Lep1Pt','Lep2Pt','Jet1Pt','Jet2Pt','HT','nConst','DilepMass','weight','nTL'])
signalHT = signal.HT
#add smearing for visualization                                                                                                                                                                                    
signal['Smear'] = np.random.normal(0,0.3,len(signal))
signal['nConstSmeared'] = signal['nConst']+signal['Smear']
signalNConst = signal.nConstSmeared

realBkg  = pd.read_csv('../data/RealBackground.csv',names = ['Lep1Pt','Lep2Pt','Jet1Pt','Jet2Pt','HT','nConst','DilepMass','weight','nTL'])
realBkgHT = realBkg.HT
#add smearing for visualization                                                                                                                                                                                    
realBkg['Smear'] = np.random.normal(0,0.3,len(realBkg))
realBkg['nConstSmeared'] = realBkg['nConst']+realBkg['Smear']
#define column data source for fakes
realSource = ColumnDataSource(data=dict(HT=[], nConst=[],weights=[]))
realBkgNConst = realBkg.nConstSmeared

#define selection for fakes
def getRealData(ht,nc):
    #selected = fakes[(fakes['HT'] >= ht) & (fakes['nConstSmeared'] >= nc)]
    selected = realBkg[
        (realBkg.HT >= ht) &
        (realBkg.nConstSmeared >= nc)
    ]
    return selected

f = p1.circle(x='HT',y='nConst',source=fakeSource, legend = 'Fake Background',size=1)
s = p1.triangle(x='HT',y='nConst',source=realSource, legend = 'Real Background', color='red',size=1)
r = p1.asterisk(signalHT,signalNConst, legend = 'Signal', color='green',size=1)

p1.legend.location = "top_right"
p1.xaxis.axis_label = 'Total Event Energy (GeV)'
p1.yaxis.axis_label = 'Number of Particles in Event'

plot = gridplot(p1, ncols=1, plot_width=400, plot_height=400, toolbar_location=None)
t = show(plot,notebook_handle=True)

def update(HT=0,nConstituents=0):
        fakesDF = getFakesData(HT,nConstituents)
        fakeSource.data = dict(HT = fakesDF['HT'], nConst = fakesDF['nConstSmeared'])
        nll = len(fakesDF[fakesDF.nTL==0])
        nlt = len(fakesDF[fakesDF.nTL==2])
        ntt = len(fakesDF[fakesDF.nTL==3])
        realDF = getRealData(HT,nConstituents)
        realSource.data = dict(HT = realDF['HT'], nConst = realDF['nConstSmeared'])
        push_notebook(handle=t)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="9f447115-a11c-4c00-a729-0121f07c0894">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="plotdiv" id="29aaeb65-3820-4489-800d-81e6bd97ad4f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#29aaeb65-3820-4489-800d-81e6bd97ad4f").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("7cbe60c7-aaf1-4463-9368-a51a898c2f7e", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("29aaeb65-3820-4489-800d-81e6bd97ad4f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '29aaeb65-3820-4489-800d-81e6bd97ad4f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"b7fcd919-505b-41ea-8454-1402b7503637":{"roots":{"references":[{"attributes":{},"id":"ff13ded0-3689-449b-a4a0-770e2a25fb70","type":"BasicTicker"},{"attributes":{"label":{"value":"Real Background"},"renderers":[{"id":"72fd0a4d-a6a0-4e87-bf9d-7282d78706a1","type":"GlyphRenderer"}]},"id":"e2612e48-fd4f-49c4-bcdf-ebc28f4deb3c","type":"LegendItem"},{"attributes":{"children":[{"id":"a89f7a0f-320c-4293-b818-91be69b543d5","type":"Row"}]},"id":"7253a7fd-8301-484e-8b4d-1f6fcd6ae08e","type":"Column"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"35f5961f-9d49-4c3e-8c1f-f32593dbc558","type":"SaveTool"}]},"id":"4e09082b-9b26-47df-87c8-2ae66b9cdf3c","type":"Toolbar"},{"attributes":{"children":[{"id":"f42662a5-4134-4152-bcf6-814de342d0c1","subtype":"Figure","type":"Plot"}]},"id":"a89f7a0f-320c-4293-b818-91be69b543d5","type":"Row"},{"attributes":{},"id":"f032c37f-8d38-4fd5-9662-cd8e5301f787","type":"BasicTickFormatter"},{"attributes":{},"id":"675eaed2-3da0-42f5-b331-497688e2a03c","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["weights","nConst","HT"],"data":{"HT":[],"nConst":[],"weights":[]}},"id":"1aeca9b4-f205-4f2e-b422-c1e4e5d1b0a3","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"f42662a5-4134-4152-bcf6-814de342d0c1","subtype":"Figure","type":"Plot"}},"id":"35f5961f-9d49-4c3e-8c1f-f32593dbc558","type":"SaveTool"},{"attributes":{"data_source":{"id":"618421f1-7f4e-4292-bbb5-d6c2032ba802","type":"ColumnDataSource"},"glyph":{"id":"e837ba65-82b4-4ea3-9f41-5ae8106d1f99","type":"Asterisk"},"hover_glyph":null,"nonselection_glyph":{"id":"e23f9a88-edfa-4944-9786-42374add2563","type":"Asterisk"},"selection_glyph":null},"id":"df53246f-9514-49e7-aed6-a67f8f0fa13d","type":"GlyphRenderer"},{"attributes":{"axis_label":"Number of Particles in Event","formatter":{"id":"f032c37f-8d38-4fd5-9662-cd8e5301f787","type":"BasicTickFormatter"},"plot":{"id":"f42662a5-4134-4152-bcf6-814de342d0c1","subtype":"Figure","type":"Plot"},"ticker":{"id":"ff13ded0-3689-449b-a4a0-770e2a25fb70","type":"BasicTicker"}},"id":"bbe6b557-fd9a-4678-adbf-fcf19dee9992","type":"LinearAxis"},{"attributes":{"items":[{"id":"802bab61-6e0c-4902-8795-0c974d76c6d9","type":"LegendItem"},{"id":"e2612e48-fd4f-49c4-bcdf-ebc28f4deb3c","type":"LegendItem"},{"id":"5608a2ba-363b-4b2f-ba99-c72357fca4a5","type":"LegendItem"}],"plot":{"id":"f42662a5-4134-4152-bcf6-814de342d0c1","subtype":"Figure","type":"Plot"}},"id":"8acb6aea-2ae6-4f83-9c68-e160fd48922b","type":"Legend"},{"attributes":{"background_fill_color":{"value":"#E8DDCB"},"below":[{"id":"73956b7c-d051-4a40-9de1-ac291c69dd47","type":"LinearAxis"}],"left":[{"id":"bbe6b557-fd9a-4678-adbf-fcf19dee9992","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"73956b7c-d051-4a40-9de1-ac291c69dd47","type":"LinearAxis"},{"id":"563033e2-9977-4992-bf1e-e371b364f078","type":"Grid"},{"id":"bbe6b557-fd9a-4678-adbf-fcf19dee9992","type":"LinearAxis"},{"id":"dafebe94-42c9-485e-a151-014ce3e57305","type":"Grid"},{"id":"8acb6aea-2ae6-4f83-9c68-e160fd48922b","type":"Legend"},{"id":"6b6296bd-d262-4c47-9cac-643365d0e0ed","type":"GlyphRenderer"},{"id":"72fd0a4d-a6a0-4e87-bf9d-7282d78706a1","type":"GlyphRenderer"},{"id":"df53246f-9514-49e7-aed6-a67f8f0fa13d","type":"GlyphRenderer"}],"title":{"id":"0c92f1c3-bf77-4783-8073-251ec43b632e","type":"Title"},"tool_events":{"id":"f02607c2-cefb-496b-b3e5-7245e4c38b97","type":"ToolEvents"},"toolbar":{"id":"4e09082b-9b26-47df-87c8-2ae66b9cdf3c","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"b20e22cc-8df0-44f4-b934-b4bed20aa7f0","type":"DataRange1d"},"y_range":{"id":"e12187df-e345-4609-a724-b09f7fe974ed","type":"DataRange1d"}},"id":"f42662a5-4134-4152-bcf6-814de342d0c1","subtype":"Figure","type":"Plot"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":1},"x":{"field":"HT"},"y":{"field":"nConst"}},"id":"4f437c96-1933-4ec9-b1ac-1b4d2429 ...

# %%
interact(update,HT=(0,1200,50),nConstituents=(0,13,1))
# Out:
# <function __main__.update>

# %%
def getNonPromptPred(ht,nc):
    p1 = figure(title="Distribution for Fake Background Prediction",
            background_fill_color="#E8DDCB")
    df = getFakesData(ht,nc)
    nll_obs = len(df[df.nTL==0])
    nlt_obs = len(df[df.nTL==1])
    ntt_obs = len(df[df.nTL==3])

    weight_ll = w_ll(0.202,0.839)
    weight_lt = w_lt(0.202,0.839)
    weight_tt = w_tt(0.202,0.839)

    n_ll = np.random.poisson(nll_obs, 10000)
    n_lt = np.random.poisson(nlt_obs, 10000)
    n_tt = np.random.poisson(ntt_obs, 10000)

    n_np = []

    for nll, nlt, ntt in zip(n_ll,n_lt,n_tt):
        n_np.append( nll*weight_ll + nlt*weight_lt + ntt*weight_tt)

    mean = np.mean(n_np)
    sigma = np.std(n_np)

    hist, edges = np.histogram(n_np, density=False, bins=50)


    p1.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:],
        fill_color="#036564", line_color="#033649")

    p1.legend.location = "top_left"
    p1.xaxis.axis_label = 'Number of Fake Background Events Predicted'
    p1.yaxis.axis_label = ''
    meantext = Label(x=230, y=350, x_units='screen', y_units='screen',
                     text='Prediction: %.1f Evts' %mean, render_mode='canvas',
                    border_line_color='black',background_fill_color='white')

    sigmatext = Label(x=230, y=330, x_units='screen', y_units='screen',
                 text='Uncert: +/- %.1f Evts' %sigma, render_mode='canvas',
                     border_line_color='black',background_fill_color='white')
    p1.add_layout(meantext)
    p1.add_layout(sigmatext)
    #make figure to hold simple text result
    sigdf = getSignalData(ht,nc)
    sig = len(sigdf) #just number of entries
    sig = sig* (12.9*44/300000) #weighting for luminosity
    res = 'Yes' if (sig > 2*sigma) else 'No'
    sigtext = Label(x=100, y=275, x_units='screen', y_units='screen',
                     text='Signal Events: %.1f Events' %mean, render_mode='canvas')
    restext = Label(x=100, y=225, x_units='screen', y_units='screen',
                     text='Sensitive? : %.1s' %res, render_mode='canvas')
    p2 = figure(title="Analysis Results")
    p2.add_layout(sigtext)
    p2.add_layout(restext)
    return p1,p2

def updatePred(HT=0,nConstituents=0):
    p1,p2 = getNonPromptPred(HT,nConstituents)
    show(gridplot(p1,p2,ncols=2,plot_width=400,plot_height=400),notebook_handle = True)
    push_notebook()

# %%
interact(updatePred,HT=(0,1200,100),nConstituents=(0,13,1))
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="c1de9be2-a174-4e5b-a25b-847751d30ed6"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#c1de9be2-a174-4e5b-a25b-847751d30ed6").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("2d404639-8a67-43c5-b38a-4492cec017f2", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c1de9be2-a174-4e5b-a25b-847751d30ed6");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c1de9be2-a174-4e5b-a25b-847751d30ed6' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"f9fbed30-7dc8-4f5e-82a9-cf9672813e4d":{"roots":{"references":[{"attributes":{"plot":{"id":"7b80c1ba-f19d-4065-a001-8a1b62607d80","subtype":"Figure","type":"Plot"}},"id":"b472193f-7fcc-4e6d-9326-b1f98b490da9","type":"HelpTool"},{"attributes":{},"id":"182639cf-2281-424a-a63f-75c072724ce1","type":"ToolEvents"},{"attributes":{"bottom":{"value":0},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"left":{"field":"left"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"field":"right"},"top":{"field":"top"}},"id":"f4fc9262-04fa-47bd-b7fb-9b11d910ca51","type":"Quad"},{"attributes":{"sizing_mode":"scale_width","toolbar_location":"above","tools":[{"id":"e939f979-b5c5-4083-b08f-f7958158c04d","type":"PanTool"},{"id":"3796a50c-3e8b-4dea-951b-df02fc403fb7","type":"WheelZoomTool"},{"id":"6e67293f-466d-4908-851a-9641436da9af","type":"BoxZoomTool"},{"id":"509b2d9c-8a43-430f-95eb-f7bf7e77735d","type":"SaveTool"},{"id":"7c61744c-8f15-49b5-a4a8-44218162356d","type":"ResetTool"},{"id":"b472193f-7fcc-4e6d-9326-b1f98b490da9","type":"HelpTool"},{"id":"6273e9ef-125c-4fbc-a0b9-d548560bf90e","type":"PanTool"},{"id":"92ade8cd-7985-467e-860c-0e04bbc60066","type":"WheelZoomTool"},{"id":"d20e1592-aa72-40e3-96b0-e78751f2632a","type":"BoxZoomTool"},{"id":"14538eb4-c845-42f8-998a-4c9372e1df53","type":"SaveTool"},{"id":"b965da9a-287a-43f1-9088-d380a797eec7","type":"ResetTool"},{"id":"a817ad74-b97d-4008-90c7-e2316eaa3472","type":"HelpTool"}]},"id":"583babbd-bad7-43ec-980c-33aea6c717ca","type":"ToolbarBox"},{"attributes":{"dimension":1,"plot":{"id":"7b80c1ba-f19d-4065-a001-8a1b62607d80","subtype":"Figure","type":"Plot"},"ticker":{"id":"4ae5f340-49ad-4c47-b044-0eb1b9d15cd4","type":"BasicTicker"}},"id":"208b11c8-5741-4d62-88b0-8c4236a19012","type":"Grid"},{"attributes":{},"id":"797a4bd3-61f0-4135-8a5d-f0b17bb55e32","type":"BasicTicker"},{"attributes":{"plot":{"id":"58d47363-4d31-448e-ab39-36c26ae2141f","subtype":"Figure","type":"Plot"}},"id":"b965da9a-287a-43f1-9088-d380a797eec7","type":"ResetTool"},{"attributes":{"plot":{"id":"7b80c1ba-f19d-4065-a001-8a1b62607d80","subtype":"Figure","type":"Plot"},"ticker":{"id":"797a4bd3-61f0-4135-8a5d-f0b17bb55e32","type":"BasicTicker"}},"id":"b7049ceb-e3c3-4a16-a199-0a313b989572","type":"Grid"},{"attributes":{},"id":"bede9b74-a577-4fb4-ad36-1bde9d0bed4c","type":"BasicTickFormatter"},{"attributes":{"bottom":{"value":0},"fill_color":{"value":"#036564"},"left":{"field":"left"},"line_color":{"value":"#033649"},"right":{"field":"right"},"top":{"field":"top"}},"id":"debdcea6-46e8-4f5a-9f23-9e6adc903d11","type":"Quad"},{"attributes":{"formatter":{"id":"432fcfc1-c81e-4f35-86ed-ec9203b4ece9","type":"BasicTickFormatter"},"plot":{"id":"58d47363-4d31-448e-ab39-36c26ae2141f","subtype":"Figure","type":"Plot"},"ticker":{"id":"8e2f3803-5ea7-454a-964c-5a2167a79087","type":"BasicTicker"}},"id":"6a33435a-d447-4291-8c24-2b2a4c9c7cbd","type":"LinearAxis"},{"attributes":{"formatter":{"id":"c6658836-7314-40b3-9207-525b706f549c","type":"BasicTickFormatter"},"plot":{"id":"7b80c1ba-f19d-4065-a001-8a1b62607d80","subtype":"Figure","type":"Plot"},"ticker":{"id":"4ae5f340-49ad-4c47-b044-0eb1b9d15cd4","type":"BasicTicker"}},"id":"e69a0752-eb8c-43d4-9f2f-9d2aead13239","type":"LinearAxis"},{"attributes":{"plot":{"id":"58d47363-4d31-448e-ab39-36c26ae2141f","subtype":"Figure","type":"Plot"}},"id":"14538eb4-c845-42f8-998a-4c9372e1df53","type":"SaveTool"},{"attributes":{"children":[{"id":"7b80c1ba-f19d-4065-a001-8a1b62607d80","subtype":"Figure","type":"Plot"},{"id":"58d47363-4d31-448e-ab39-36c26ae2141f","subtype":"Figure","type":"Plot"}]},"id":"60e149c5-049d-49c3-ba7d-5962b53ef6db","type":"Row"},{"attributes":{"background_fill_color":{"value":"white"},"border_line_color":{"value":"black"},"plot":{"id":"7b80c1ba-f19d-4065-a001-8a1b62607d80","subtype":"Figure","type":"Plot"},"text":"Prediction: 1.3 Evts","x":230,"x_units":"screen","y":350,"y_units":"screen"},"id":"44aee56f-0dfb-4622-b356-2a372b5f4588","typ ...
