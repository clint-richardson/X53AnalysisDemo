# %%
import numpy as np
import scipy.special
import pandas as pd

from bokeh.layouts import gridplot
from bokeh.plotting import figure
from bokeh.models import Range1d, ColumnDataSource, Label
from ipywidgets import interact
from bokeh.io import show, push_notebook, output_notebook
output_notebook()

#get helper weights function for nonprompt
from Weights import *

p1 = figure(title="",tools="save",
            background_fill_color="#E8DDCB")

#read in fakes
fakes  = pd.read_csv('../data/FakeBackground.csv',names = ['Lep1Pt','Lep2Pt','Jet1Pt','Jet2Pt','HT','nConst','DilepMass','weight','nTL'])
#add smearing for visualization                                                                                                                                                                                    
fakes['Smear'] = np.random.normal(0,0.3,len(fakes))
fakes['nConstSmeared'] = fakes['nConst']+fakes['Smear']
#define column data source for fakes
fakeSource = ColumnDataSource(data=dict(HT=[], nConst=[],weights=[]))

#define selection for fakes
def getFakesData(ht,nc):
    #selected = fakes[(fakes['HT'] >= ht) & (fakes['nConstSmeared'] >= nc)]
    selected = fakes[
        (fakes.HT >= ht) &
        (fakes.nConstSmeared >= nc)
    ]
    return selected

#read in signal
signal  = pd.read_csv('../data/Signal.csv',names = ['Lep1Pt','Lep2Pt','Jet1Pt','Jet2Pt','HT','nConst','DilepMass','weight','nTL'])
signalHT = signal.HT
#add smearing for visualization                                                                                                                                                                                    
signal['Smear'] = np.random.normal(0,0.3,len(signal))
signal['nConstSmeared'] = signal['nConst']+signal['Smear']
signalNConst = signal.nConstSmeared

def getSignalData(ht,nc):
    selected = signal[
        (signal.HT >= ht) &
        (signal.nConst >= nc)
    ]
    return selected

realBkg  = pd.read_csv('../data/RealBackground.csv',names = ['Lep1Pt','Lep2Pt','Jet1Pt','Jet2Pt','HT','nConst','DilepMass','weight','nTL'])
realBkgHT = realBkg.HT
#add smearing for visualization                                                                                                                                                                                    
realBkg['Smear'] = np.random.normal(0,0.3,len(realBkg))
realBkg['nConstSmeared'] = realBkg['nConst']+realBkg['Smear']
#define column data source for fakes
realSource = ColumnDataSource(data=dict(HT=[], nConst=[],weights=[]))
realBkgNConst = realBkg.nConstSmeared

#define selection for fakes
def getRealData(ht,nc):
    #selected = fakes[(fakes['HT'] >= ht) & (fakes['nConstSmeared'] >= nc)]
    selected = realBkg[
        (realBkg.HT >= ht) &
        (realBkg.nConstSmeared >= nc)
    ]
    return selected

f = p1.circle(x='HT',y='nConst',source=fakeSource, legend = 'Fake Background',size=1)
s = p1.triangle(x='HT',y='nConst',source=realSource, legend = 'Real Background', color='red',size=1)
r = p1.asterisk(signalHT,signalNConst, legend = 'Signal', color='green',size=1)

p1.legend.location = "top_right"
p1.xaxis.axis_label = 'Total Event Energy (GeV)'
p1.yaxis.axis_label = 'Number of Particles in Event'

plot = gridplot(p1, ncols=1, plot_width=400, plot_height=400, toolbar_location=None)
t = show(plot,notebook_handle=True)

def update(HT=0,nConstituents=0):
        fakesDF = getFakesData(HT,nConstituents)
        fakeSource.data = dict(HT = fakesDF['HT'], nConst = fakesDF['nConstSmeared'])
        nll = len(fakesDF[fakesDF.nTL==0])
        nlt = len(fakesDF[fakesDF.nTL==2])
        ntt = len(fakesDF[fakesDF.nTL==3])
        realDF = getRealData(HT,nConstituents)
        realSource.data = dict(HT = realDF['HT'], nConst = realDF['nConstSmeared'])
        push_notebook(handle=t)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="b621833f-fe73-4359-b575-fe18b709cdde">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="plotdiv" id="14d29b8c-f55e-4620-8583-4d017a18b51e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#14d29b8c-f55e-4620-8583-4d017a18b51e").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("93ab6785-7e33-405c-a406-6445827f8145", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("14d29b8c-f55e-4620-8583-4d017a18b51e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '14d29b8c-f55e-4620-8583-4d017a18b51e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"25b65b74-a8b0-4b61-b1ea-48d4370e7711":{"roots":{"references":[{"attributes":{"children":[{"id":"fb5d52a0-9bc8-4b78-a42e-1c3da5c5c3b2","type":"Row"}]},"id":"0c1f6bbd-4547-4222-8b6e-9be9f2a92539","type":"Column"},{"attributes":{"plot":null,"text":""},"id":"96231113-dea3-44ef-8555-265bba130a82","type":"Title"},{"attributes":{"fill_color":{"value":"red"},"line_color":{"value":"red"},"size":{"units":"screen","value":1},"x":{"field":"HT"},"y":{"field":"nConst"}},"id":"12f9a848-f8b7-4158-b9ff-fae36e83a306","type":"Triangle"},{"attributes":{"data_source":{"id":"e9136bc7-9161-44bf-845f-150748d57829","type":"ColumnDataSource"},"glyph":{"id":"12f9a848-f8b7-4158-b9ff-fae36e83a306","type":"Triangle"},"hover_glyph":null,"nonselection_glyph":{"id":"9a21bc25-5e36-47f8-86b3-baf9e4c1e455","type":"Triangle"},"selection_glyph":null},"id":"82661b34-314d-4cc8-8e15-55953fe1f88f","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":1},"x":{"field":"x"},"y":{"field":"y"}},"id":"13ba4196-e0f6-4957-831b-66a7f210867b","type":"Asterisk"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"873b75a2-f8b9-435c-adce-c1b0dccdbedd","type":"SaveTool"}]},"id":"542dfb54-a584-4ff0-aa5b-b8040044417c","type":"Toolbar"},{"attributes":{"plot":{"id":"02adc472-5b29-4ac9-9b03-77c61535ccd3","subtype":"Figure","type":"Plot"}},"id":"873b75a2-f8b9-435c-adce-c1b0dccdbedd","type":"SaveTool"},{"attributes":{},"id":"edb713b0-9236-401e-b52a-9e58932b81a7","type":"BasicTickFormatter"},{"attributes":{},"id":"96fd3b33-cee7-431c-9028-422f3dd7c232","type":"ToolEvents"},{"attributes":{"callback":null},"id":"49e2b647-bd79-4ac0-978e-7044cdca6f25","type":"DataRange1d"},{"attributes":{"label":{"value":"Fake Background"},"renderers":[{"id":"b39d28cc-f383-4035-84a4-11df387ad198","type":"GlyphRenderer"}]},"id":"9e2e32d3-ee69-4c4b-9a93-1c5a47daa6d4","type":"LegendItem"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":1},"x":{"field":"HT"},"y":{"field":"nConst"}},"id":"6745c62a-f90e-455d-b86c-ee28d734dfc8","type":"Circle"},{"attributes":{},"id":"8eaaecfb-606e-42f2-ab33-4940815b44ca","type":"BasicTicker"},{"attributes":{"background_fill_color":{"value":"#E8DDCB"},"below":[{"id":"a354a26e-2057-48ff-9ebc-ace53f67e47b","type":"LinearAxis"}],"left":[{"id":"727989b9-2aaf-4eac-8df1-9e079f581ed6","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"a354a26e-2057-48ff-9ebc-ace53f67e47b","type":"LinearAxis"},{"id":"ac4d114f-c7c2-48ee-bb4f-f8cf1443290b","type":"Grid"},{"id":"727989b9-2aaf-4eac-8df1-9e079f581ed6","type":"LinearAxis"},{"id":"b31c18d3-bb17-4ed0-a80b-78f1c8553c5d","type":"Grid"},{"id":"f763d13f-a77a-4903-a629-82ca6f1b236f","type":"Legend"},{"id":"b39d28cc-f383-4035-84a4-11df387ad198","type":"GlyphRenderer"},{"id":"82661b34-314d-4cc8-8e15-55953fe1f88f","type":"GlyphRenderer"},{"id":"8ad60dcd-e6f6-4331-9d71-c74c53598ea2","type":"GlyphRenderer"}],"title":{"id":"96231113-dea3-44ef-8555-265bba130a82","type":"Title"},"tool_events":{"id":"96fd3b33-cee7-431c-9028-422f3dd7c232","type":"ToolEvents"},"toolbar":{"id":"542dfb54-a584-4ff0-aa5b-b8040044417c","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"900108cc-c8d3-4f77-bff6-2d14a7936249","type":"DataRange1d"},"y_range":{"id":"49e2b647-bd79-4ac0-978e-7044cdca6f25","type":"DataRange1d"}},"id":"02adc472-5b29-4ac9-9b03-77c61535ccd3","subtype":"Figure","type":"Plot"},{"attributes":{"children":[{"id":"02adc472-5b29-4ac9-9b03-77c61535ccd3","subtype":"Figure","type":"Plot"}]},"id":"fb5d52a0-9bc8-4b78-a42e-1c3da5c5c3b2","type":"Row"},{"attributes":{"callback":null,"column_names":["weights","nConst","HT"],"data":{"HT":[],"nConst":[],"weights":[]}},"id":"e3c9baab-cb97-451c-aefe-8a068ce07801","type":"Colum ...

# %%
interact(update,HT=(0,1200,50),nConstituents=(0,13,1))
# Out:
# <function __main__.update>

# %%
def getNonPromptPred(ht,nc):
    p1 = figure(title="Distribution for Fake Background Prediction",
            background_fill_color="#E8DDCB")
    df = getFakesData(ht,nc)
    nll_obs = len(df[df.nTL==0])
    nlt_obs = len(df[df.nTL==1])
    ntt_obs = len(df[df.nTL==3])

    weight_ll = w_ll(0.202,0.839)
    weight_lt = w_lt(0.202,0.839)
    weight_tt = w_tt(0.202,0.839)

    n_ll = np.random.poisson(nll_obs, 10000)
    n_lt = np.random.poisson(nlt_obs, 10000)
    n_tt = np.random.poisson(ntt_obs, 10000)

    n_np = []

    for nll, nlt, ntt in zip(n_ll,n_lt,n_tt):
        n_np.append( nll*weight_ll + nlt*weight_lt + ntt*weight_tt)

    mean = np.mean(n_np)
    sigma = np.std(n_np)

    hist, edges = np.histogram(n_np, density=False, bins=50)


    p1.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:],
        fill_color="#036564", line_color="#033649")

    p1.legend.location = "top_left"
    p1.xaxis.axis_label = 'Number of Fake Background Events Predicted'
    p1.yaxis.axis_label = ''
    meantext = Label(x=230, y=350, x_units='screen', y_units='screen',
                     text='Prediction: %.1f Evts' %mean, render_mode='canvas',
                    border_line_color='black',background_fill_color='white')

    sigmatext = Label(x=230, y=330, x_units='screen', y_units='screen',
                 text='Uncert: +/- %.1f Evts' %sigma, render_mode='canvas',
                     border_line_color='black',background_fill_color='white')
    p1.add_layout(meantext)
    p1.add_layout(sigmatext)
    #make figure to hold simple text result
    sigdf = getSignalData(ht,nc)
    sig = len(sigdf) #just number of entries
    sig = sig* (12.9*21*.8/300000) #weighting for luminosity
    res = 'Yes' if (sig > 2*sigma) else 'No'
    sigtext = Label(x=100, y=275, x_units='screen', y_units='screen',
                     text='Signal Events: %.1f Events' %sig, render_mode='canvas')
    restext = Label(x=100, y=225, x_units='screen', y_units='screen',
                     text='Sensitive? : %.1s' %res, render_mode='canvas')
    p2 = figure(title="Analysis Results")
    p2.add_layout(sigtext)
    p2.add_layout(restext)
    return p1,p2

def updatePred(EventEnergy=0,nParticles=0):
    p1,p2 = getNonPromptPred(EventEnergy,nParticles)
    show(gridplot(p1,p2,ncols=2,plot_width=400,plot_height=400),notebook_handle = True)
    push_notebook()

# %%
interact(updatePred,EventEnergy=(0,1200,100),nParticles=(0,13,1))
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="48ddbe9d-6b32-483b-8f95-82f4d62f7d13"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#48ddbe9d-6b32-483b-8f95-82f4d62f7d13").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("cd7e38cb-bd92-4272-a516-14efece19f39", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("48ddbe9d-6b32-483b-8f95-82f4d62f7d13");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '48ddbe9d-6b32-483b-8f95-82f4d62f7d13' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"7a510d85-8607-4dd6-9886-5251eea9ec2e":{"roots":{"references":[{"attributes":{"children":[{"id":"1ea09bdc-4065-4ddc-9ae6-74016f49a397","type":"ToolbarBox"},{"id":"cbc291b9-4be3-4b1e-af33-42aee9949b57","type":"Column"}]},"id":"801efa46-2c3c-4d76-8d82-21ff3947c2a4","type":"Column"},{"attributes":{"bottom":{"value":0},"fill_color":{"value":"#036564"},"left":{"field":"left"},"line_color":{"value":"#033649"},"right":{"field":"right"},"top":{"field":"top"}},"id":"170f5c62-8ba5-4e33-a910-2276839df625","type":"Quad"},{"attributes":{"formatter":{"id":"f59685ad-1d08-499c-b4e6-05fc26786432","type":"BasicTickFormatter"},"plot":{"id":"fc2f80de-7a16-4c9a-ab40-a3991f5caa67","subtype":"Figure","type":"Plot"},"ticker":{"id":"55476605-6803-474d-af84-aa94846b0a85","type":"BasicTicker"}},"id":"e73bc387-f36a-40c0-921b-7485a901161d","type":"LinearAxis"},{"attributes":{"dimension":1,"plot":{"id":"fee495bd-a986-4c1b-9f70-8db838c54833","subtype":"Figure","type":"Plot"},"ticker":{"id":"12b0966f-685e-4cb8-9154-527dee35770f","type":"BasicTicker"}},"id":"575fc1a6-d612-44f8-8627-ffa3ced24764","type":"Grid"},{"attributes":{"callback":null},"id":"1c7b465e-7e50-494d-8eab-0d613ae7e849","type":"DataRange1d"},{"attributes":{},"id":"5994a131-15f2-47ee-ba1f-22252239f03a","type":"BasicTicker"},{"attributes":{"plot":null,"text":"Distribution for Fake Background Prediction"},"id":"24b30787-198e-4592-b943-30bc57ca3544","type":"Title"},{"attributes":{"plot":{"id":"fc2f80de-7a16-4c9a-ab40-a3991f5caa67","subtype":"Figure","type":"Plot"}},"id":"07230585-f178-4975-9fa4-aaa2dd9c6a9c","type":"WheelZoomTool"},{"attributes":{},"id":"c3f38709-799b-4ba1-89b6-e36f357c984e","type":"BasicTicker"},{"attributes":{},"id":"55476605-6803-474d-af84-aa94846b0a85","type":"BasicTicker"},{"attributes":{"background_fill_color":{"value":"white"},"border_line_color":{"value":"black"},"plot":{"id":"fee495bd-a986-4c1b-9f70-8db838c54833","subtype":"Figure","type":"Plot"},"text":"Prediction: 43.3 Evts","x":230,"x_units":"screen","y":350,"y_units":"screen"},"id":"05734cb4-0407-4fc6-bc48-cc59c82e29bb","type":"Label"},{"attributes":{},"id":"f59685ad-1d08-499c-b4e6-05fc26786432","type":"BasicTickFormatter"},{"attributes":{},"id":"5fceab8d-7584-4392-b13c-167a7fa77b4c","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"fee495bd-a986-4c1b-9f70-8db838c54833","subtype":"Figure","type":"Plot"}},"id":"b463cd6d-18cf-46e8-b02a-4be110691372","type":"SaveTool"},{"attributes":{"callback":null,"column_names":["right","top","left"],"data":{"left":[28.682796541598776,29.32300614781571,29.96321575403265,30.603425360249584,31.24363496646652,31.883844572683458,32.52405417890039,33.16426378511733,33.80447339133426,34.4446829975512,35.08489260376814,35.725102209985074,36.36531181620201,37.005521422418944,37.64573102863588,38.285940634852814,38.92615024106975,39.56635984728669,40.206569453503626,40.84677905972056,41.486988665937496,42.12719827215443,42.76740787837137,43.4076174845883,44.04782709080524,44.68803669702218,45.32824630323911,45.96845590945605,46.60866551567298,47.248875121889924,47.88908472810685,48.529294334323794,49.16950394054073,49.80971354675766,50.449923152974606,51.09013275919153,51.730342365408475,52.37055197162541,53.010761577842345,53.65097118405928,54.291180790276215,54.93139039649316,55.571600002710085,56.21180960892703,56.85201921514396,57.4922288213609,58.13243842757783,58.772648033794766,59.41285764001171,60.053067246228636],"right":[29.32300614781571,29.96321575403265,30.603425360249584,31.24363496646652,31.883844572683458,32.52405417890039,33.16426378511733,33.80447339133426,34.4446829975512,35.08489260376814,35.725102209985074,36.36531181620201,37.005521422418944,37.64573102863588,38.285940634852814,38.92615024106975,39.56635984728669,40.206569453503626,40.84677905972056,41.486988665937496,42.12719827215443,42.76740787837137,43.4076174845883,44.04782709080524,44.68803669702218,45.32824630323911,45.96845590945605,46.60866551567298,47.248875121889924,47.889084 ...
